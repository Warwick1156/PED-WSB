# %%
import os
import sys
src_dir = os.path.join('..', 'src')
sys.path.append(os.path.abspath(src_dir))

from tqdm import tqdm
from math import ceil

from data import get_dataset, save_dataset
from reddit_api import Praw
from multiprocessing_ import parallelize_dataframe

tqdm.pandas()

# %%
data = get_dataset('dataset_1.00c.csv')
# Out:
# ../../data/datasets/dataset_1.00c.csv

# %%
reddit = Praw()

# %%
part.drop(columns=part.columns[1:], inplace=True)

# %%
def get_num_comments(df):
    df.loc[:, 'num_comments'] = [reddit.get_submission(id_).num_comments for id_ in tqdm(df.id)]

# %%
data.drop(columns=data.columns[1:], inplace=True)

# %%
num_comments_df = parallelize_dataframe(data, get_num_comments)
# Out:
# ...
#   0%|          | 0/9727 [00:00<?, ?it/s]
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 576, in _handle_results
#     task = get()
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 251, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
#   File "/home/kira/.local/lib/python3.8/site-packages/prawcore/exceptions.py", line 43, in __init__
#     f"received {response.status_code} HTTP response"
# AttributeError: 'str' object has no attribute 'status_code'
#
# ...
#   3%|▎         | 249/9727 [11:59<9:45:55,  3.71s/it]
# ...
# ...
#  17%|█▋        | 1663/9727 [1:18:05<6:49:11,  3.04s/it]Process ForkPoolWorker-2:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-1:
# ...

# %%
save_dataset(num_comments_df, 'num_comments.csv')
