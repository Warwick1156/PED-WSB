# %%
import os
import sys

src_dir = os.path.join('..', 'src')
sys.path.append(os.path.abspath(src_dir))

from forecasting import make, train_test_split
from models import lstm1, lstm2, lstm3
from data import get_dataset

# %%
data = get_dataset('timeseries_v4.1.csv')
train, test = train_test_split(data)
# Out:
# ../../data/datasets/timeseries_v4.1.csv

# %% [markdown]
# # Predykcja z użyciem przyrostu komentarzy w czasie

# %% [markdown]
# ## Model 1

# %% [markdown]
# ### Wykorzystanie danych z pierwszej godizny

# %%
make(lstm1, train, test, past=6*1, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm1_1_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:06<00:00, 1138.42it/s]
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 21.11714, saving model to ../../data/model/lstm1_1_24.h5
#
# ...

# %% [markdown]
# ### Wykorzystanie danych z pierwszych dwóch godzin

# %%
make(lstm1, train, test, past=6*2, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm1_2_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:06<00:00, 1055.70it/s]
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 12, 1)]           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 18.76990, saving model to ../../data/model/lstm1_2_24.h5
#
# ...

# %% [markdown]
# ### Wykorzystanie danych z pierwszych pięciu godzin

# %%
make(lstm1, train, test, past=6*5, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm1_5_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:06<00:00, 1074.75it/s]
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Epoch 00001: val_loss improved from inf to 24.64730, saving model to ../../data/model/lstm1_5_24.h5
#
# ...

# %% [markdown]
# ## Model 2

# %%
make(lstm2, train, test, past=6*1, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm2_1_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:07<00:00, 1026.53it/s]
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# lstm (LSTM)                  (None, 6, 64)             16896
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# ...

# %%
make(lstm2, train, test, past=6*2, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm2_2_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:06<00:00, 1094.56it/s]
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 12, 1)]           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 12, 64)            16896
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# ...

# %%
make(lstm2, train, test, past=6*5, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm2_5_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:07<00:00, 1026.51it/s]
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 30, 64)            16896
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# ...

# %% [markdown]
# # Model 3

# %%
make(lstm3, train, test, past=6*1, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm3_1_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:07<00:00, 980.95it/s]
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         [(None, 6, 1)]            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 6, 32)             4352
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 136
# ...

# %%
make(lstm3, train, test, past=6*2, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm3_2_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:06<00:00, 1104.81it/s]
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         [(None, 12, 1)]           0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 12, 32)            4352
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 136
# ...

# %%
make(lstm3, train, test, past=6*5, future=6*24, epochs=100, n_charts=5, seed=42, name='lstm3_5_24', verbose=0)
# Out:
# ...
# 100%|██████████| 7197/7197 [00:07<00:00, 917.50it/s]
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 30, 1)]           0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 30, 32)            4352
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 16)                3136
# _________________________________________________________________
# ...
